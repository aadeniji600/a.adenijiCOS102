# %%
from tkinter import *

window = Tk()
window.geometry('1000x1000')

label_7 =Label(window, text="PAU CAFETERIA",font = "times 30 bold")
label_7.place(x=500,y=0)
    
label_1 =Label(window, text="MENU",font = "times 28 bold")
label_1.place(x=850,y=60)

label_2 =Label(window,text="RICE/PASTA",font = "times 20 bold")
label_2.place(x=850,y=120)
label_21 =Label(window,text="Jollof rice - 350",font = "times 18 bold")
label_21.place(x=850,y=150)
label_22 =Label(window,text="Coconut fried rice - 350",font = "times 18 bold")
label_22.place(x=850,y=180)
label_23 =Label(window,text="Jollof spaghetti - 350",font = "times 18 bold")
label_23.place(x=850,y=210)

label_3 =Label(window,text="PROTEINS",font = "times 20 bold")
label_3.place(x=850,y=270)
label_31 =Label(window,text="Sweet chili chicken - 1100",font = "times 18 bold")
label_31.place(x=850,y=300)
label_32 =Label(window,text="Grilled chicken wings - 400",font = "times 18 bold")
label_32.place(x=850,y=330)
label_33 =Label(window,text="Fried beef - 400",font = "times 18 bold")
label_33.place(x=850,y=360)
label_34 =Label(window,text="Fried fish - 500",font = "times 18 bold")
label_34.place(x=850,y=390)
label_35 =Label(window,text="Boiled egg - 200",font = "times 18 bold")
label_35.place(x=850,y=420)
label_36 =Label(window,text="Sauteed sausages - 200",font = "times 18 bold")
label_36.place(x=850,y=450)

label_4 =Label(window,text="SOUPS & SWALLOWS",font = "times 20 bold")
label_4.place(x=850,y=510)
label_41 =Label(window,text="Eba - 100",font = "times 18 bold")
label_41.place(x=850,y=540)
label_42 =Label(window,text="Poundo yam - 100",font = "times 18 bold")
label_42.place(x=850,y=570)
label_43 =Label(window,text="Semo - 100",font = "times 18 bold")
label_43.place(x=850,y=600)
label_44 =Label(window,text="Atama soup - 450",font = "times 18 bold")
label_44.place(x=850,y=630)
label_45 =Label(window,text="Egusi soup - 490",font = "times 18 bold")
label_45.place(x=850,y=660)

label_5 =Label(window,text="SIDE DISHES",font = "times 20 bold")
label_5.place(x=850,y=720)
label_51 =Label(window,text="Savoury beans - 350",font = "times 18 bold")
label_51.place(x=850,y=750)
label_52 =Label(window,text="Roasted sweet potatoes - 300",font = "times 18 bold")
label_52.place(x=850,y=780)
label_53 =Label(window,text="Fried plantains - 150",font = "times 18 bold")
label_53.place(x=850,y=810)
label_54 =Label(window,text="Mixed vegetable salad - 150",font = "times 18 bold")
label_54.place(x=850,y=840)
label_55 =Label(window,text="Boiled yam - 150",font = "times 18 bold")
label_55.place(x=850,y=870)

label_6 =Label(window,text="BEVRAGES",font = "times 20 bold")
label_6.place(x=850,y=930)
label_61 =Label(window,text="Water - 200",font = "times 18 bold")
label_61.place(x=850,y=960)
label_62 =Label(window,text="Glass drink (35cl) - 150",font = "times 18 bold")
label_62.place(x=850,y=990)
label_63 =Label(window,text="PET drink (35cl) - 300",font = "times 18 bold")
label_63.place(x=850,y=1020)
label_64 =Label(window,text="PET drink (50cl) - 450",font = "times 18 bold")
label_64.place(x=850,y=1050)
label_65 =Label(window,text="Glass/Canned malt - 500",font = "times 18 bold")
label_65.place(x=850,y=1080)
label_66 =Label(window,text="Fresh yo - 600",font = "times 18 bold")
label_66.place(x=850,y=1110)
label_67 =Label(window,text="Pineapple juice - 350",font = "times 18 bold")
label_67.place(x=850,y=1140)
label_68 =Label(window,text="Mango juice - 350",font = "times 18 bold")
label_68.place(x=850,y=1170)
label_68 =Label(window,text="Zobo drink - 350",font = "times 18 bold")
label_68.place(x=850,y=1200)

window.mainloop()
