# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomeMessage(name):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This is Python GUI with Tkinter")
    label_2.pack()

    # Run the Tkinter event loop
    root.mainloop()

def submit():
    name = name_entry.get()
    department = department_entry.get()
    password = password_entry.get()

    if name == "ADENIRAN Oluwatamilore" or "ADEWUMI	Ayomide" or "ADOH-AJAGBE Oshim" or "AGBAKURU- NWOGU Chukwunonye" or "AGBAKWURU Chiemeziem" or "AKINDE Oluwatimilehin" or "ARNIKA Osose" or "ATELLY Daniel" or "AZOGU Onyekachi" or "BETURE Shalom" or "CHUKWUMA	Nedi" or "EBI Stephanie" or "EGBORO	Jason" or "EJEDIMU	Edward" or "ELERI Otu" or "EZE	Onyinyechi" or "EZEONYE	Makuochukwu" or "GIWA	Moyosore" or "ICHA Ayonete" or "IKPATI Eche" or "ILOENYOSI Michael" or "IYAWE Oluwadamilola" or "NWOKOLO Chijindu" or "NWOTOKUBO Joseph" or "OBASOGIE Daisy" or "OBI Samuel" or "OBIALOR Betha" or "OGBONNA Boluwatife" or "OIGBOCHIE Mary" or "OKOCHA-OJEAH Raphael" or "OKOLO	Victor" or "OKORO Derek" or "OLOWOKERE Akorede" or "OLUBUADE Rasheed" or "OSEMEKE Daniel" or "OSSAI Mary-Cynthia" or "PETER	Owoede" or "QUADRI Oluwafikunmi" or "UDE-IBE Uchenna" or "UMEH Ejike" and department == "Logistics" or "Accounting" or "Delivery" or "Administration" and password == "INT101":
        welcomeMessage(name)
    else:
        messagebox.showerror("Login", "Invalid Name, Department or Password")

# Create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("500x200")

# Create name label and entry
name_label = tk.Label(root, text="Name:")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

# Create department label and entry
department_label = tk.Label(root, text="Department:")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()

#Create password label and entry
password_label = tk.Label(root, text="Password:")
password_label.pack()
password_entry = tk.Entry(root, show="*")
password_entry.pack()


# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
