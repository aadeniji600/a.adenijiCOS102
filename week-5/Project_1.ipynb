# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def log(surname):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("ARAMI LOGISTICS SECTOR")
    window.geometry('500x300')

    label_1 = tk.Label(window, text=f'\nLOGISTICS SECTOR WORKERS\n')
    label_1.pack()
    label_3=tk.Label(window,text='\nNAMES :\n1)ADENIRAN Oluwatamilore  \n2)AGBAKWURU Chiemeziem \n3)ARNIKA Osose \n4)CHUKWUMA Nedi \n5)EZEONYE Makuochukwu \n6)GIWA Moyosore \n7)NWOKOLO Chijindu \n8)NWOTOKUBO	Joseph \n9)OKORO Derek \n10)OSSAI Mary-Cynthia \n11)PETER Owoede')
    label_3.pack()

def acc(surname):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("ARAMI ACCOUNTING SECTOR")
    window.geometry('500x300')

    label_1 = tk.Label(window, text=f'\nACCOUNTING SECTOR WORKERS\n')
    label_1.pack()
    label_3=tk.Label(window,text='\nNAMES :\n1)ADEWUMI Ayomide  \n2)AGBAKURU-NWOGU Chukwunonye \n3)AKINDE Oluwatimehin \n4)EBI Stephanie \n5)ICHA Ayonete \n6)IKPATI Eche \n7)OBAOSGIE Daisy \n8)OBI Samuel \n9)OBIALOR Betha \n10)OLOWOKERE Akorede \n11)OLUBUADE Rasheed \n12)OSEMEKE Daniel')
    label_3.pack()

def deli(surname):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("ARAMI DELIVERY SECTOR")
    window.geometry('500x300')

    label_1 = tk.Label(window, text=f'\nDELIVERY SECTOR WORKERS\n')
    label_1.pack()
    label_3=tk.Label(window,text='\nNAMES :\n1)ADOH-AJAGBE Oshim \n2)ATELLY Daniel \n3)AZOGU Onyekachi \n4)BETURE Shalom \n5)EJEDIMU Edward \n6)ILOENYOSI Michael \n7)IYAWE Oluwadamilola \n8)OGBONNA Boluwatife \n9)OIGBOCHIE Mary \n10)QUADRI Oluwafikunmi \n11)UDE-IBE Uchenna')
    label_3.pack()

def admin(surname):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("ARAMI ADMINISTRATION SECTOR")
    window.geometry('500x300')

    label_1 = tk.Label(window, text=f'\nADMINISTRATION SECTOR WORKERS\n')
    label_1.pack()
    label_3=tk.Label(window,text='\nNAMES :\n1)EGBORO Jason \n2)ELERI Otu \n3)EZE Onyiyechi \n4)OKOCHA-OJEAH Raphael \n5)Okolo Victor \n6)UMEH Ejike')
    label_3.pack()

    
    #run the tkinter event loop
    root.mainloop()    
    
def submit():
    surname = surname_entry.get()
    sector = sector_entry.get()
    
    if surname == 'ADENIRAN' or surname == 'AGBAKWURU' or surname == 'ARNIKA' or surname == 'CHUKWUMA' or surname == 'EZEONYE'or surname == 'GIWA' or surname == 'NWOKOLO' or surname == 'NWOTOKUBO' or surname == 'OKORO' or surname == 'OSSAI' or surname == 'PETER':
        if sector == 'Logistics':
            messagebox.showinfo("Success",f"Welcome {surname}")
            log(surname)
                        
    elif surname == 'ADEWUMI' or surname == 'AGBAKURU-NWOGU' or surname== 'AKINDE' or surname == 'EBI' or surname == 'ICHA' or surname == 'IKPATI' or surname == 'OBAOSGIE' or surname == 'OBI' or surname == 'OBIALOR' or surname == 'OLOWOKERE' or surname == 'OLUBUADE' or surname == 'OSEMEKE':
        if sector =='Accounting':
            messagebox.showinfo("Success",f"Welcome {surname}")
            acc(surname)
            
    elif surname == 'ADOH-AJAGBE' or surname == 'ATELLY' or surname == 'AZOGU' or surname == 'BETURE' or surname == 'EJEDIMU' or surname == 'ILOENYOSI' or surname == 'IYAWE' or surname == 'OGBONNA' or surname == 'OIGBOCHIE' or surname == 'QUADRI' or surname == 'UDE-IBE':
        if sector =='Delivery':
            messagebox.showinfo("Success",f"Welcome {surname}")
            deli(surname)
            
    elif surname == 'EGBORO' or surname == 'ELERI' or surname == 'EZE' or surname == 'OKOACHA-OJEAH' or surname == 'OKOLO' or surname == 'UMEH':
        if sector =='Administration':
            messagebox.showinfo("Success",f"Welcome {surname}")
            admin(surname)
        
    else:
        messagebox.showerror('Sign in','Invalid surname or sector')

#create main window
root = tk.Tk()
root.title('ARAMI ESSENTIALS INC.')
root.geometry('500x200')

# Create surname label and entry
surname_label = tk.Label(root, text="Surame (Write in capital letters):")
surname_label.pack()
surname_entry = tk.Entry(root)
surname_entry.pack()

# Create sector label and entry
sector_label = tk.Label(root, text = 'Sector (First letter in capital):')
sector_label.pack()
sector_entry = tk.Entry(root)
sector_entry.pack()

# Create submit button
submit_button = tk.Button(root, text = 'Submit', command=submit)
submit_button.pack()

# Styling the button widget
submit_button.config(fg = 'black', bg = 'green')

# Run the main event loop
root.mainloop()
