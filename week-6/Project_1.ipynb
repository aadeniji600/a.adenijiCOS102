# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def log(name):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("SIMI LOGISTIC SERVICES")
    window.geometry('500x300')

def deli(name):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("SIMI LOGISTICS SERVICES")
    window.geometry('500x300')
    
    label_1 = tk.Label(window, text=f'\nTHANK YOU FOR CHOOSING SIMI LOGISTICS SERVICES\n')
    label_1.pack()
    label_3=tk.Label(window,text=f'\nYour delivery fee is N10,000\n')
    label_3.pack()

def acc(name):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("SIMI LOGISTICS SERVICES")
    window.geometry('500x300')
    
    label_1 = tk.Label(window, text=f'\nTHANK YOU FOR CHOOSING SIMI LOGISTICS SERVICES\n')
    label_1.pack()
    label_3=tk.Label(window,text=f'\nYour delivery fee is N5,000\n')
    label_3.pack()

def admin(name):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("SIMI LOGISTICS SERVICES")
    window.geometry('500x300')
    
    label_1 = tk.Label(window, text=f'\nTHANK YOU FOR CHOOSING SIMI LOGISTICS SERVICES\n')
    label_1.pack()
    label_3=tk.Label(window,text=f'\nYour delivery fee is N3,500\n')
    label_3.pack()

def telly(name):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("SIMI LOGISTICS SERVICES")
    window.geometry('500x300')
    
    label_1 = tk.Label(window, text=f'\nTHANK YOU FOR CHOOSING SIMI LOGISTICS SERVICES\n')
    label_1.pack()
    label_3=tk.Label(window,text=f"\nYour delivery fee is N5,000\n")
    label_3.pack()


def submit():
    name = name_entry.get()
    location = location_entry.get()
    weight = int(weight_entry.get())
    
    if location == 'ibeju lekki' and weight >= 10:
        messagebox.showinfo("Success",f"Welcome {name}")
        acc(name)

    elif location == 'ibeju lekki' and weight < 10:
        messagebox.showinfo("Success",f"Welcome {name}")
        admin(name)

    elif location == 'epe' and weight >= 10:
        messagebox.showinfo("Success",f"Welcome {name}")
        deli(name)

    elif location == 'epe' and weight < 10:
        messagebox.showinfo("Success",f"Welcome {name}")
        telly(name)
    else:
        messagebox.showerror(f"Sorry, We do not deliver to this address.")

#create main window
root = tk.Tk()
root.title('SIMI LOGISTIC SERVICES')
root.geometry('500x200')

# Create Name label and entry
name_label = tk.Label(root, text="Name :")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

# Create weight label and entry
weight_label = tk.Label(root, text="State the weight of your package (Value should be in kg):")
weight_label.pack()
weight_entry = tk.Entry(root)
weight_entry.pack()

# Create location label and entry
location_label = tk.Label(root, text = 'Is your delivery address in Ibeju lekki or Epe :')
location_label.pack()
location_entry = tk.Entry(root)
location_entry.pack()

# Create submit button
submit_button = tk.Button(root, text = 'Submit', command=submit)
submit_button.pack()

# Styling the button widget
submit_button.config(fg = 'black', bg = 'orange')

# Run the main event loop
root.mainloop()
