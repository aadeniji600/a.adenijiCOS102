# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def log(score):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("MINISO COLLEGE PORTAL")
    window.geometry('500x300')

def acc(name,score,course):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("MINISO COLLEGE PORTAL")
    window.geometry('500x300')
    
    label_1 = tk.Label(window, text=f'\nWELCOME\n')
    label_1.pack()
    label_3=tk.Label(window, text=f'\nHello {name}, your jamb score is {score}.\nYou were not accepted into the {course} class of 2024/2028, because you failed to meet one of their requirements')
    label_3.pack()
    
def telly(name,score,course):
     #create a tkinter window
    window = tk.Toplevel(root)
    window.title("MINISO COLLEGE PORTAL")
    window.geometry('500x300')
    
    label_1 = tk.Label(window, text=f'\nWELCOME\n')
    label_1.pack()
    label_3=tk.Label(window, text=f'\nHello {name}, your jamb score is {score}, you passed an interview and have at least 5 credits in the 5 key subjects.\nYou have been accepted into the {course} class of 2024/2028')
    label_3.pack()

def stelly(name,score,course):
     #create a tkinter window
    window = tk.Toplevel(root)
    window.title("MINISO COLLEGE PORTAL")
    window.geometry('500x300')
    
    label_1 = tk.Label(window, text=f'\nWELCOME\n')
    label_1.pack()
    label_3=tk.Label(window, text=f'\nHello {name}, your jamb score is {score}, you passed an interview and have at least 5 credits in the 5 key subjects.\nYou have been accepted into the {course} class of 2024/2028')
    label_3.pack()



def submit():
    name = name_entry.get()
    course = course_entry.get()
    key = key_entry.get()
    interview = interview_entry.get()
    score = int(score_entry.get())

    if course == "computer science" and key == 'yes' and interview == "yes" and score >= 250:
        messagebox.showinfo("Success",f"Welcome {name}")
        telly(name,score,course)

    elif course == "mass communication" and key == 'yes' and interview == "yes" and score >= 230:
        messagebox.showinfo("Success",f"Welcome {name}")
        stelly(name,score,course) 

    else:
        messagebox.showinfo("Success",f"Welcome {name}")
        acc(name,score,course)
        

#create main window
root = tk.Tk()
root.title('MINISO COLEGE PORTAL')
root.geometry('500x200')

# Create Name label and entry
name_label = tk.Label(root, text="Name :")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

# Create Course label and entry
course_label = tk.Label(root, text="Course :")
course_label.pack()
course_entry = tk.Entry(root)
course_entry.pack()

# Create Key label and entry
key_label = tk.Label(root, text="Did you have at least 5 credits in the 5 key subjects (yes or no) :")
key_label.pack()
key_entry = tk.Entry(root)
key_entry.pack()

# Create Interview label and entry
interview_label = tk.Label(root, text="Did you pass an interview (yes or no) :")
interview_label.pack()
interview_entry = tk.Entry(root)
interview_entry.pack()

# Create Score label and entry
score_label = tk.Label(root, text="You jamb score is :")
score_label.pack()
score_entry = tk.Entry(root)
score_entry.pack()

# Create submit button
submit_button = tk.Button(root, text = 'Submit', command=submit)
submit_button.pack()

# Styling the button widget
submit_button.config(fg = 'black', bg = 'orange')

# Run the main event loop
root.mainloop()
