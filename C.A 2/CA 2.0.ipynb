# %%
from tkinter import *
from tkinter import messagebox

window = Tk()
window.geometry('1000x1000')
window.title("PAU CAFETERIA")
        
def click (name):
    jrice = int (e1.get()) * 350
    cfrice = int (e2.get()) * 350
    spag = int (e3.get()) * 350
    chicken = int (e4.get()) * 1100
    wings = int (e5.get()) * 400
    beef = int (e6.get()) * 400
    fish = int (e7.get()) * 500
    egg = int (e8.get()) * 200
    sausage = int (e9.get()) * 200
    eba = int (e10.get()) * 100
    poundo = int (e11.get()) * 100
    semo = int (e12.get()) * 100
    atama = int (e13.get()) * 450
    egusi = int (e14.get()) * 490
    beans = int (e15.get()) * 350
    potatoes = int (e16.get()) * 300
    plantain = int (e17.get()) * 150
    salad = int (e18.get()) * 150
    yam = int (e19.get()) * 150
    water = int (e20.get()) * 200
    glass = int (e21.get()) * 150
    drink1 = int (e22.get()) * 300
    drink2 = int (e23.get()) * 450
    malt = int (e24.get()) * 500
    freshyo = int (e25.get()) * 400
    pineapple = int (e26.get()) * 350
    mango =int (e27.get()) * 350
    zobo = int (e28.get()) * 350
    # print(type(zobo))
    total = jrice + cfrice + spag + chicken + wings + beef + fish + egg + sausage + eba + poundo + semo + atama + egusi + beans + potatoes + plantain + salad + yam + water + glass + drink1 + drink2 + malt + freshyo + pineapple + mango + zobo

    # Display a welcome message if the total is less than 1000
    if total < 1000:
        bill = total
        messagebox.showinfo("Welcome", "Thank you for your order!")

    # Open a new window to display the total
        total_window = Toplevel(window)
        total_window.geometry('400x200')
        total_window.title("BILL")

        label_100= Label(total_window, text=f'\nHello {name}', font="times 15 bold")
        label_100.pack()
    
        label_50 = Label(total_window, text=f"Your bill is: {bill}", font="times 15 bold")
        label_50.pack(pady=40)

    if total < 2500 and total > 1000:
        bill = total * 0.9
        messagebox.showinfo("Discount", "You have received a 10% discount.")
        
    elif total < 5000 and total > 2500:
        bill = total * 0.85
        messagebox.showinfo("Discount", "You have received a 15% discount.")
      
    elif total > 5000:
        bill = total * 0.75
        messagebox.showinfo("Discount", "You have received a 25% discount")

    
# Open a new window to display the total
    total_window = Toplevel(window)
    total_window.geometry('400x200')
    total_window.title("BILL")

    label_3= Label(total_window, text=f'\nHello {name}', font="times 15 bold")
    label_3.pack()

    label_40 = Label(total_window, text=f"Your bill before the discount was: {total}\n Your bill now is {bill}", font="times 15 bold")
    label_40.pack(pady=40)

    total_window.mainloop()

name_entry = Entry(window)
name_entry.place(x=1200, y=380)
    
# Creating the menu
label_7 =Label(window, text="PAU CAFETERIA MENU",font = "constantia 30 bold")
label_7.place(x=600,y=20,anchor = "center")

# Billing section
label_8 =Label(window,text = "Input the amount of portions of each meal you'd like.",font= "constantia 20 bold")
label_8.place(x=70,y=70)

label_2 =Label(window,text="RICE/PASTA",font = "constantia 20 bold")
label_2.place(x=20,y=120)

label_9 =Label(window,text = "Jollof rice - 350",font= "constantia 15")
label_9.place(x=20,y=170)
e1 = Spinbox(from_=0, to=10, width=5)
e1.place(x=20,y=200)

label_10 =Label(window,text = "Coconut fried rice - 350",font= "constantia 15")
label_10.place(x=20,y=220)
e2 = Spinbox(from_=0, to=10, width=5)
e2.place(x=20,y=250)

label_11 =Label(window,text = "Jollof spaghetti - 350",font= "constantia 15")
label_11.place(x=20,y=270)
e3 = Spinbox(from_=0, to=10, width=5)
e3.place(x=20,y=300)

label_3 =Label(window,text="PROTEINS",font = "constantia 20 bold")
label_3.place(x=20,y=320)

label_12 =Label(window,text = "Sweet chili chicken - 1100",font= "constantia 15")
label_12.place(x=20,y=370)
e4 = Spinbox(from_=0, to=10, width=5)
e4.place(x=20,y=400)

label_13 =Label(window,text = "Grilled chicken wings - 400",font= "constantia 15")
label_13.place(x=20,y=420)
e5 = Spinbox(from_=0, to=10, width=5)
e5.place(x=20,y=450)

label_14 =Label(window,text = "Fried beef - 400",font= "constantia 15")
label_14.place(x=20,y=470)
e6 = Spinbox(from_=0, to=10, width=5)
e6.place(x=20,y=500)

label_15 =Label(window,text = "Fried fish - 500",font= "constantia 15")
label_15.place(x=20,y=520)
e7 = Spinbox(from_=0, to=10, width=5)
e7.place(x=20,y=550)

label_16 =Label(window,text = "Boiled egg - 200",font= "constantia 15")
label_16.place(x=20,y=570)
e8 = Spinbox(from_=0, to=10, width=5)
e8.place(x=20,y=600)

label_17 =Label(window,text = "Sauteed sausages - 200",font= "constantia 15")
label_17.place(x=20,y=620)
e9 = Spinbox(from_=0, to=10, width=5)
e9.place(x=20,y=650)

label_4 =Label(window,text="SOUPS & SWALLOWS",font = "constantia 20 bold")
label_4.place(x=370,y=140)

label_18 =Label(window,text = "Eba - 100",font= "constantia 15")
label_18.place(x=370,y=190)
e10 = Spinbox(from_=0, to=10, width=5)
e10.place(x=370,y=220)

label_19 =Label(window,text = "Poundo yam - 100",font= "constantia 15")
label_19.place(x=370,y=240)
e11 = Spinbox(from_=0, to=10, width=5)
e11.place(x=370,y=270)

label_20 =Label(window,text = "Semo - 100",font= "constantia 15")
label_20.place(x=370,y=290)
e12 = Spinbox(from_=0, to=10, width=5)
e12.place(x=370,y=320)

label_21 =Label(window,text = "Atama soup - 450",font= "constantia 15")
label_21.place(x=370,y=340)
e13 = Spinbox(from_=0, to=10, width=5)
e13.place(x=370,y=370)

label_22 =Label(window,text = "Egusi soup - 490",font= "constantia 15")
label_22.place(x=370,y=390)
e14 = Spinbox(from_=0, to=10, width=5)
e14.place(x=370,y=420)

label_5 =Label(window,text="SIDE DISHES",font = "constantia 20 bold")
label_5.place(x=370,y=440)

label_23 =Label(window,text = "Savoury beans - 350",font= "constantia 15")
label_23.place(x=370,y=490)
e15 = Spinbox(from_=0, to=10, width=5)
e15.place(x=370,y=520)

label_24 =Label(window,text = "Roasted sweet potatoes - 300",font= "constantia 15")
label_24.place(x=370,y=540)
e16 = Spinbox(from_=0, to=10, width=5)
e16.place(x=370,y=570)

label_25 =Label(window,text = "Fried plantains - 150",font= "constantia 15")
label_25.place(x=370,y=590)
e17 = Spinbox(from_=0, to=10, width=5)
e17.place(x=370,y=620)

label_26 =Label(window,text = "Mixed vegetable salad - 150",font= "constantia 15")
label_26.place(x=370,y=640)
e18 = Spinbox(from_=0, to=10, width=5)
e18.place(x=370,y=670)

label_27 =Label(window,text = "Boiled yam - 150",font= "constantia 15")
label_27.place(x=370,y=690)
e19 = Spinbox(from_=0, to=10, width=5)
e19.place(x=370,y=720)

label_6 =Label(window,text="BEVERAGES",font = "constantia 20 bold")
label_6.place(x=700,y=140)

label_28 =Label(window,text = "Water - 200",font= "constantia 15")
label_28.place(x=700,y=190)
e20 = Spinbox(from_=0, to=10, width=5)
e20.place(x=700,y=220)

label_29 =Label(window,text = "Glass drink (35cl) - 150",font= "constantia 15")
label_29.place(x=700,y=240)
e21 = Spinbox(from_=0, to=10, width=5)
e21.place(x=700,y=270)

label_30 =Label(window,text = "PET drink (35cl) - 300",font= "constantia 15")
label_30.place(x=700,y=290)
e22 = Spinbox(from_=0, to=10, width=5)
e22.place(x=700,y=320)

label_31 =Label(window,text = "PET drink (50cl) - 450", font= "constantia 15")
label_31.place(x=700,y=340)
e23 = Spinbox(from_=0, to=10, width=5)
e23.place(x=700,y=370)

label_32 =Label(window,text = "Glass/Canned malt - 500", font= "constantia 15")
label_32.place(x=700,y=390)
e24 = Spinbox(from_=0, to=10, width=5)
e24.place(x=700,y=420)

label_33 =Label(window,text = "Fresh yo - 400", font= "constantia 15")
label_33.place(x=700,y=440)
e25 = Spinbox(from_=0, to=10, width=5)
e25.place(x=700,y=470)

label_34 =Label(window,text = "Pineapple juice 350", font= "constantia 15")
label_34.place(x=700,y=490)
e26 = Spinbox(from_=0, to=10, width=5)
e26.place(x=700,y=520)

label_35 =Label(window,text = "Mango juice - 350", font= "constantia 15")
label_35.place(x=700,y=540)
e27 = Spinbox(from_=0, to=10, width=5)
e27.place(x=700,y=570)

label_36 =Label(window,text = "Zobo drink - 350", font= "constantia 15")
label_36.place(x=700,y=590)
e28 = Spinbox(from_=0, to=10, width=5)
e28.place(x=700,y=620)

# Create Name label and entry
name_label = Label(window, text="Name :")
name_label.place(x=1200, y=350)
name_entry = Entry(window)
name_entry.place(x=1200, y=380)

# Button to trigger the order
b2 = Button(window, text='ORDER', width=30, command=lambda: click(name_entry.get()))
b2.place(x=1200, y=450)

window.mainloop()

# %% [markdown]
# PSEUDOCODE FOR THIS CODE
# 1. Set up variables for each menu item and their respective prices.
# 2. Create a function to handle the order button:
#    a. Retrieve the quantity of each menu item from the Spinbox widgets.
#    b. Calculate the total bill based on the quantity of each item and its price.
#    c. Determine if the total bill is eligible for a discount based on given conditions.
#    d. If the total bill is less than 1000, display a welcome message.
#    e. If the total bill qualifies for a discount, calculate the discounted bill.
#    f. Display a message indicating the original bill and, if applicable, the discounted bill.
# 3. Create a Tkinter window with appropriate dimensions and title.
# 4. Add labels and Spinbox widgets for each menu item to the window.
# 5. Add a text entry for the customer's name.
# 6. Add an "ORDER" button that triggers the click function.
# 7. Display the Tkinter window and start the event loop.
