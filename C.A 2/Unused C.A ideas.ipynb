# %%
#def submit():
  # rice = e1.get()
  # proteins = e2.get()
  # soups = e3.get()
  # sides = e4.get()
  # beverages = e5.get()
    
  # if rice == 'Jollof rice' or rice == 'Coconut fried rice' or rice == 'Jollof spaghetti':
  # if proteins == 'Sweet chili chicken' or proteins == 'Grilled chicken wings' or proteins == 'Fried beef' or proteins == 'Fried fish' or proteins == 'Boiled egg' or proteins == 'Sauteed sausages':
  # if soups == 'Eba' or soups == 'Poundo yam' or soups == 'Semo' or soups == 'Atama soup' or soups == 'Egusi soup':
  # if sides == 'Savoury beans' or sides == ''

# %%
from tkinter import *

window = Tk()
window.geometry('1000x1000')
window.title("PAU CAFETERIA")

# Creating the menu
label_7 =Label(window, text="PAU CAFETERIA MENU",font = "Constantia 30 bold")
label_7.place(x=600,y=20,anchor = "center")

label_9 =Label(window,text="Rice/Pasta",font = "Constantia 20 bold")
label_9.place(x=20,y=120)
e1 =Entry(window)
e1.place(x=20,y=150)
e11 =Entry (window)
e11.place(x=200,y=150)
    
label_10 =Label(window,text="Proteins",font = "Constantia 20 bold")
label_10.place(x=20,y=200)
e2 =Entry(window)
e2.place(x=20,y=230)
e21 =Entry (window)
e21.place(x=200,y=230)
    
label_11 =Label(window,text="Soups & Swallows",font = "Constantia 20 bold")
label_11.place(x=20,y=280)
e3 =Entry(window)
e3.place(x=20,y=310)
e31 =Entry (window)
e31.place(x=200,y=310)

    
label_12 =Label(window,text="Side Dishes",font = "Constantia 20 bold")
label_12.place(x=20,y=360)
e4 =Entry(window)
e4.place(x=20,y=390)
e41 =Entry (window)
e41.place(x=200,y=390)
    
label_13 =Label(window,text="Beverages",font = "Constantia 20 bold")
label_13.place(x=20,y=440)
e5 =Entry(window)
e5.place(x=20,y=470)
e51 =Entry (window)
e51.place(x=200,y=470)

# Calculating the total
def calculate():
    price1 = e11.get()
    price2 = e21.get()
    price3 = e31.get()
    price4 = e41.get()
    price5 = e51.get()
    print(type(price5))
    total = ((int(price1)) + (int(price2)) + (int(price3)) + (int(price4)) + (int(price5)))
    #label_14 =Label(window, text ="Your total bill is:", font = "times 18 bold")

    if total < 2500:
        bill = total * 0.1
        messagebox.showinfo("Success")
        telly()
    
    elif total > 2500 and total < 5000:
        bill = total * 0.15
        messagebox.showinfo("Success")
        stelly()

    elif total > 5000:
        bill = total *0.25
        messagebox.showinfo("Success")
        chill()
        
    else:total < 1000
    bill = total
    messagebox.showinfo("Success")
    still()

def telly():
    #create a tkinter window
    window = Tk()
    window.geometry("400x500")
    label_1 =Label(window, text=f'Thank you {name}, for choosing PAU Cafeteria')
    label_1.pack()
    label_3=Label(window,text='')
    label_3.pl
        
b2 = Button(window,text='TOTAL', width=20, command=calculate)
b2.place(x=20,y=520)

# Billing section
label_8 =Label(window,text = "Input the meals you want from each section, please write items exactly the way they're listed in the menu with the prices.",font= "times 20 bold")
label_8.place(x=70,y=70)

label_2 =Label(window,text="RICE/PASTA",font = "Constantia 20 bold")
label_2.place(x=850,y=120)
label_21 =Label(window,text="Jollof rice - 350",font = "Constantia 18 bold")
label_21.place(x=850,y=150)
label_22 =Label(window,text="Coconut fried rice - 350",font = "Constantia 18 bold")
label_22.place(x=850,y=180)
label_23 =Label(window,text="Jollof spaghetti - 350",font = "Constantia 18 bold")
label_23.place(x=850,y=210)

label_3 =Label(window,text="PROTEINS",font = "Constantia 20 bold")
label_3.place(x=850,y=270)
label_31 =Label(window,text="Sweet chili chicken - 1100",font = "Constantia 18 bold")
label_31.place(x=850,y=300)
label_32 =Label(window,text="Grilled chicken wings - 400",font = "Constantia 18 bold")
label_32.place(x=850,y=330)
label_33 =Label(window,text="Fried beef - 400",font = "Constantia 18 bold")
label_33.place(x=850,y=360)
label_34 =Label(window,text="Fried fish - 500",font = "Constantia 18 bold")
label_34.place(x=850,y=390)
label_35 =Label(window,text="Boiled egg - 200",font = "Constantia 18 bold")
label_35.place(x=850,y=420)
label_36 =Label(window,text="Sauteed sausages - 200",font = "Constantia 18 bold")
label_36.place(x=850,y=450)

label_4 =Label(window,text="SOUPS & SWALLOWS",font = "constantia 20 bold")
label_4.place(x=850,y=510)
label_41 =Label(window,text="Eba - 100",font = "constantia 18 bold")
label_41.place(x=850,y=540)
label_42 =Label(window,text="Poundo yam - 100",font = "constantia 18 bold")
label_42.place(x=850,y=570)
label_43 =Label(window,text="Semo - 100",font = "Constantia 18 bold")
label_43.place(x=850,y=600)
label_44 =Label(window,text="Atama soup - 450",font = "Constantia 18 bold")
label_44.place(x=850,y=630)
label_45 =Label(window,text="Egusi soup - 490",font = "Constantia 18 bold")
label_45.place(x=850,y=660)

label_5 =Label(window,text="SIDE DISHES",font = "Constanntia 20 bold")
label_5.place(x=1200,y=120)
label_51 =Label(window,text="Savoury beans - 350",font = "Constantia 18 bold")
label_51.place(x=1200,y=150)
label_52 =Label(window,text="Roasted sweet potatoes - 300",font = "Constantia 18 bold")
label_52.place(x=1200,y=180)
label_53 =Label(window,text="Fried plantains - 150",font = "Constantia 18 bold")
label_53.place(x=1200,y=210)
label_54 =Label(window,text="Mixed vegetable salad - 150",font = "Constantia 18 bold")
label_54.place(x=1200,y=240)
label_55 =Label(window,text="Boiled yam - 150",font = "Constantia 18 bold")
label_55.place(x=1200,y=270)

label_6 =Label(window,text="BEVRAGES",font = "Constantia 20 bold")
label_6.place(x=1200,y=330)
label_61 =Label(window,text="Water - 200",font = "Constantia 18 bold")
label_61.place(x=1200,y=360)
label_62 =Label(window,text="Glass drink (35cl) - 150",font = "Constantia 18 bold")
label_62.place(x=1200,y=390)
label_63 =Label(window,text="PET drink (35cl) - 300",font = "Constantia 18 bold")
label_63.place(x=1200,y=420)
label_64 =Label(window,text="PET drink (50cl) - 450",font = "Constantia 18 bold")
label_64.place(x=1200,y=450)
label_65 =Label(window,text="Glass/Canned malt - 500",font = "Constantia 18 bold")
label_65.place(x=1200,y=480)
label_66 =Label(window,text="Fresh yo - 600",font = "Constantia 18 bold")
label_66.place(x=1200,y=510)
label_67 =Label(window,text="Pineapple juice - 350",font = "Constantia 18 bold")
label_67.place(x=1200,y=540)
label_68 =Label(window,text="Mango juice - 350",font = "Constantia 18 bold")
label_68.place(x=1200,y=570)
label_68 =Label(window,text="Zobo drink - 350",font = "Constantia 18 bold")
label_68.place(x=1200,y=600)

window.mainloop()
